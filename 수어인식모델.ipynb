# %% [markdown]
# <a href="https://colab.research.google.com/github/gaegoori/handsignproject/blob/main/%EC%88%98%EC%96%B4%EC%9D%B8%EC%8B%9D%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Drive 마운트
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %%bash
# SRC="/content/drive/MyDrive/keypoints_all"
# DST="/content/drive/MyDrive/keypoints_160F"
#
# mkdir -p "$DST"
#
# echo "정확한 WORD0001~0160 + REAL01~16 + F 버전만 추출 시작"
#
# for z in "$SRC"/*.zip; do
#     echo "ZIP 처리 중: $z"
#
#     # word 숫자 범위만 포함 (0001~0160)
#     for i in $(seq -f "%04g" 1 160); do
#         unzip -qq "$z" "*/NIA_SL_WORD${i}_REAL*_F*" -d "$DST"
#     done
# done
#
# echo "추출 완료"
# echo "저장 위치: $DST"
# Out:
# Process is terminated.

# %%
import os
from zipfile import ZipFile

zip_path = "/content/drive/MyDrive/01_real_word_morpheme.zip"
extract_to = "/content/drive/MyDrive/morpheme_full"

os.makedirs(extract_to, exist_ok=True)

with ZipFile(zip_path, 'r') as zf:
    zf.extractall(extract_to)

print("압축해제 완료:", extract_to)
# Out:
# 압축해제 완료: /content/drive/MyDrive/morpheme_full

# %%
import os, json, glob
from tqdm import tqdm

# 0. 경로 설정
# Keypoint 폴더의 루트 경로
keypoint_root = "/content/drive/MyDrive/keypoints_160F"
# Morpheme 파일의 루트 경로
morpheme_root = "/content/drive/MyDrive/morpheme_full/morpheme"
# 최종 JSON 파일이 저장될 경로
output_dir = "/content/drive/MyDrive/sign_data/fast_index"

os.makedirs(output_dir, exist_ok=True)


# 1. WORD 0001 ~ 0160 생성
selected_words = {f"NIA_SL_WORD{str(i).zfill(4)}" for i in range(1, 161)}
print(f"선택된 단어 수: {len(selected_words)}개 ")



# 2. morpheme 파일 로드 및 REAL ID 딕셔너리 생성
morpheme_files = glob.glob(os.path.join(morpheme_root, "**/*.json"), recursive=True)
morpheme_dict = {}

def extract_real_id_from_morpheme(filename):
    # NIA_SL_WORD0001_REAL02_morpheme.json → NIA_SL_WORD0001_REAL02 추출
    name = os.path.basename(filename).replace("_morpheme.json", "")
    return name.rsplit("_", 1)[0]

for f in tqdm(morpheme_files, desc="Morpheme 파일 로드"):
    real_id = extract_real_id_from_morpheme(f)
    base_word = real_id.split("_REAL")[0] # NIA_SL_WORD0001

    # 선택된 단어에 포함되는 경우에만 딕셔너리에 추가
    if base_word in selected_words:
        # REAL ID를 고유 키로 사용하여 1:1 매칭 준비
        morpheme_dict[real_id] = f

print(f"필터링된 morpheme (REAL ID 기준) 개수: {len(morpheme_dict)}개")


# 3. keypoint 폴더 로드 (F 측면)
keypoint_dirs = []

for root, dirs, files in os.walk(keypoint_root):
    for d in dirs:
        # 예: NIA_SL_WORD0001_REAL03_F 형식의 폴더만 선택
        if d.startswith("NIA_SL_WORD") and "_REAL" in d and d.endswith("_F"):
            keypoint_dirs.append(os.path.join(root, d))

print(f"선택된 keypoint 폴더 수: {len(keypoint_dirs)}개")


def extract_real_id_from_kp(folder_name):
    # NIA_SL_WORD0001_REAL03_F → NIA_SL_WORD0001_REAL03 추출
    return folder_name.rsplit("_", 1)[0]


# 4. keypoint ↔ morpheme 1:1 매칭 및 fast_index 생성
fast_index = []

for kp_path in tqdm(keypoint_dirs, desc="단어 매칭 중"):
    folder_name = os.path.basename(kp_path)

    # 1:1 매칭을 위한 REAL ID 추출
    real_id = extract_real_id_from_kp(folder_name)

    # base_word 추출 (선택된 단어 확인용)
    base_word = real_id.split("_REAL")[0]

    # base_word가 선택 목록에 있고, 해당 REAL ID의 morpheme 파일이 morpheme_dict에 있는 경우 매칭
    if base_word in selected_words and real_id in morpheme_dict:
        morpheme_path = morpheme_dict[real_id]

        fast_index.append({
            "word_id": base_word,
            "real_id": real_id, # 매칭된 고유 ID
            "keypoint_path": kp_path,
            "morpheme_path": morpheme_path
        })

print(f"최종 매칭된 데이터 개수: {len(fast_index)}개")



# 5. JSON 저장
output_path = os.path.join(output_dir, "fast_match.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(fast_index, f, indent=4, ensure_ascii=False)

print("\n 저장 완료:", output_path)
# Out:
# 선택된 단어 수: 160개 (160개면 정상)
# Morpheme 파일 로드: 100%|██████████| 159672/159672 [00:00<00:00, 353926.36it/s]
# 필터링된 morpheme (REAL ID 기준) 개수: 1760개
# 선택된 keypoint 폴더 수: 2560개
# 단어 매칭 중: 100%|██████████| 2560/2560 [00:00<00:00, 105017.59it/s]
# 최종 매칭된 데이터 개수: 1760개
#
#  저장 완료: /content/drive/MyDrive/sign_data/fast_index/fast_match.json

# %%
# !pip install ujson
# Out:
# Collecting ujson
#   Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.4 kB)
# Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: ujson
# Successfully installed ujson-5.11.0

# %%
import os, json, ujson, numpy as np
from tqdm import tqdm
from multiprocessing import Pool, cpu_count

# 0. 경로 설정
fast_index_path = "/content/drive/MyDrive/sign_data/fast_index/fast_match.json"
output_path = "/content/drive/MyDrive/sign_data/processed/merged_dataset.json"

os.makedirs(os.path.dirname(output_path), exist_ok=True)

# 매칭 인덱스 처리
try:
    with open(fast_index_path, "r", encoding="utf-8") as f:
        pairs = json.load(f)
except FileNotFoundError:
    print(f"오류: fast_index 파일이 경로에 없습니다. 경로를 확인해주세요: {fast_index_path}")
    pairs = []
except Exception as e:
    print(f"오류: fast_index 파일 로드 중 예외 발생: {e}")
    pairs = []

print(f"처리할 매칭 쌍 개수: {len(pairs)}개")


# 1. Keypoint 데이터 로드 및 정제 함수
def load_person_data(fp):
    try:
        with open(fp, "r") as f:
            kf = ujson.load(f)
    except:
        return None

    people = kf.get("people", [])
    if isinstance(people, dict):
        people = [people.get("0", people)]

    if not people:
        return None

    person = people[0]

    def safe_array(key):
        arr = person.get(key, [])
        if not arr:
            return np.zeros((0, 3), dtype=np.float32)

        arr = np.array(arr, dtype=np.float32)
        return arr.reshape(-1, 3)

    # Keypoint 추출 및 연결 순서: Pose(25) + LeftHand(21) + RightHand(21) + Face(70) = 137 Keypoints
    p = safe_array("pose_keypoints_2d")
    lh = safe_array("hand_left_keypoints_2d")
    rh = safe_array("hand_right_keypoints_2d")
    face = safe_array("face_keypoints_2d")

    # 모든 키포인트 연결
    full = np.concatenate([p, lh, rh, face], axis=0)

    return full



# 2. 병렬 처리 함수
def process_item(item):
    keypoint_dir = item["keypoint_path"]
    morpheme_path = item["morpheme_path"]
    fps = 30 # 초당 프레임 수 (NIA 수어 데이터셋 표준)
    real_id = item.get("real_id", "N/A")

    # Morpheme
    try:
        with open(morpheme_path, "r", encoding="utf-8") as f:
            mor = ujson.load(f)
        segments = mor.get("data", [])
        if not isinstance(segments, list):
             segments = [segments]
    except Exception:
        return []

    # Keypoint
    frame_files = sorted([
        os.path.join(keypoint_dir, f)
        for f in os.listdir(keypoint_dir)
        if f.endswith(".json")
    ])

    if not frame_files:
        return []

    # 모든 프레임 데이터 로드
    frames = []
    for fp in frame_files:
        full = load_person_data(fp)
        # 키포인트 개수 확인 (137개 = 25+21+21+70)
        if full is not None and full.shape[0] == 137:
            frames.append(full)

    if not frames:
        return []

    frames = np.stack(frames).astype(np.float32)
    results = []

    # 형태소 구간별 잘라서 저장
    for seg in segments:
        try:
            start_idx = int(seg["start"] * fps)
            end_idx = int(seg["end"] * fps)

            # 유효성 검사
            if start_idx >= len(frames) or end_idx <= start_idx:
                continue

            # 프레임 자르기
            cut = frames[start_idx:min(end_idx, len(frames))]

            results.append({
                "word_id": item["word_id"],
                "real_id": real_id,
                "label": seg["attributes"], # 형태소 레이블
                "frames": cut.tolist() # 넘파이 배열을 리스트로 변환
            })
        except Exception:
             continue

    return results


# 3. 단어 전체를 병렬 처리 및 데이터 병합
merged_data = []
if pairs:
    # CPU 코어 수만큼 Pool 생성
    core_count = cpu_count()
    print(f"사용 가능한 CPU 코어 수: {core_count}")
    with Pool(core_count) as P:
        for res in tqdm(P.imap_unordered(process_item, pairs), total=len(pairs), desc="데이터 결합 중"):
            merged_data.extend(res)


# 4. JSON 저장 (ujson 사용)
if merged_data:
    try:
        print("\n데이터를 JSON 파일로 저장 중...")
        with open(output_path, "w") as f:
            ujson.dump(merged_data, f)

        print("\n 완료")
        print(f"최종 저장된 형태소 세그먼트 개수: {len(merged_data)}개")
        print(f"경로: {output_path}")
    except Exception as e:
        print(f"저장 오류: {e}")
else:
    print("\n 처리된 데이터가 없어 저장하지 않습니다.")
# Out:
# 처리할 매칭 쌍 개수: 1760개
# 사용 가능한 CPU 코어 수: 2
# 데이터 결합 중: 100%|██████████| 1760/1760 [10:22:26<00:00, 21.22s/it]
# 데이터를 JSON 파일로 저장 중...
#
# ✅ 완료
# 최종 저장된 형태소 세그먼트 개수: 1757개
# 경로: /content/drive/MyDrive/sign_data/processed/merged_dataset.json

# %%
import numpy as np
import json
from collections import Counter
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# 1. 파일 로드
file_path = '/content/drive/MyDrive/sign_data/processed/merged_dataset.json'

print("데이터 로드...")
with open(file_path, 'r') as f:
    data_json = json.load(f)
print("로드 완료. 총 세그먼트 수:", len(data_json))


# 2. 라벨 오타 수정 + 샘플 2개 미만 라벨 제거
label_fix_map = {
    "꽈베기": "꽈배기",
    "배추국": "배춧국",
    "된장찌게": "된장찌개",
    "결승전1": "결승전",
}

data_fixed = []
for item in data_json:
    name = item['label'][0]['name']
    item['label'][0]['name'] = label_fix_map.get(name, name)
    data_fixed.append(item)

# 빈도 세기
labels_all = [item['label'][0]['name'] for item in data_fixed]
freq = Counter(labels_all)
remove_labels = [k for k, v in freq.items() if v < 2]

print("제거할 라벨들:", remove_labels)

# 필터링된 최종 데이터
filtered = [
    item for item in data_fixed
    if item['label'][0]['name'] not in remove_labels
]

print("정제 후 세그먼트 수:", len(filtered))


# 3. frames padding → raw_data 생성
keypoint_data_list = [item["frames"] for item in filtered]

print("padding 중...")
padded_data = pad_sequences(keypoint_data_list, padding='post', dtype='float32')
raw_data = np.array(padded_data)
print("raw_data shape:", raw_data.shape)   # (N, T, 137, 3)


# 4. 4D → (N,T,F) reshape
N, T, P, C = raw_data.shape
F = P * C
raw_flat = raw_data.reshape(N, T, F)
print("reshape 완료:", raw_flat.shape)


# 5. Mid-Hip 상대좌표
def apply_midhip_relative(raw):
    print("Mid-Hip 상대좌표 변환 중...")

    N, T, F = raw.shape
    num_points = F // 3

    arr = raw.reshape(N, T, num_points, 3)

    REF = 0  # Mid-Hip index
    ref_xy = arr[:, :, REF, :2]      # (N,T,2)
    ref_xy = ref_xy[:, :, None, :]   # (N,T,1,2)

    arr[:, :, :, :2] -= ref_xy       # x,y만 기준점 빼기

    return arr.reshape(N, T, F)

X_midhip = apply_midhip_relative(raw_flat)
print("Mid-Hip 완료:", X_midhip.shape)


# 6. 핵심 keypoint 선택 (18개 → 54차원: 18 * (x,y,conf))
POSE_IDXS = [0,1,2,3,4,5,6,7]
HAND_IDXS = [4,8,12,16,20]

def select_keypoints(frame_137x3):
    pose = frame_137x3[:25]
    lh   = frame_137x3[25:46]
    rh   = frame_137x3[46:67]

    selected = []
    for idx in POSE_IDXS: selected.append(pose[idx])
    for idx in HAND_IDXS: selected.append(lh[idx])
    for idx in HAND_IDXS: selected.append(rh[idx])

    return np.array(selected).reshape(-1)   # (18*3,)


def apply_keypoint_selection(X):
    print("핵심 keypoint 선택 중...")
    N, T, F = X.shape
    num_points = F // 3
    Xr = X.reshape(N, T, num_points, 3)

    X_new = np.zeros((N, T, 54), dtype=np.float32)

    for i in range(N):
        for t in range(T):
            X_new[i, t] = select_keypoints(Xr[i, t])

    print("완료:", X_new.shape)
    return X_new

X_selected = apply_keypoint_selection(X_midhip)


# 7. 강화된 interpolation (v2)
def interpolate_strong(frames, th=0.5):
    T, F = frames.shape
    P = F // 3
    arr = frames.reshape(T, P, 3)

    for p in range(P):  # 각 keypoint마다 처리
        conf = arr[:, p, 2]
        x = arr[:, p, 0]
        y = arr[:, p, 1]

        # 1) forward fill
        for t in range(1, T):
            if conf[t] < th and conf[t-1] >= th:
                x[t] = x[t-1]
                y[t] = y[t-1]
                conf[t] = conf[t-1]

        # 2) backward fill
        for t in range(T-2, -1, -1):
            if conf[t] < th and conf[t+1] >= th:
                x[t] = x[t+1]
                y[t] = y[t+1]
                conf[t] = conf[t+1]

        # 3) segment-based interpolation
        low_idx = np.where(conf < th)[0]

        if len(low_idx) > 0:
            seg_starts = []
            seg_ends = []

            start = low_idx[0]
            prev = low_idx[0]

            for idx in low_idx[1:]:
                if idx != prev + 1:
                    seg_starts.append(start)
                    seg_ends.append(prev)
                    start = idx
                prev = idx
            seg_starts.append(start)
            seg_ends.append(prev)

            # 각 연속 구간 보간
            for s, e in zip(seg_starts, seg_ends):
                prev_t = s - 1
                next_t = e + 1

                if prev_t < 0 or next_t >= T:
                    continue

                for t in range(s, e+1):
                    ratio = (t - s + 1) / (e - s + 2)
                    x[t] = (1-ratio) * x[prev_t] + ratio * x[next_t]
                    y[t] = (1-ratio) * y[prev_t] + ratio * y[next_t]
                    conf[t] = max(conf[prev_t], conf[next_t])

        arr[:, p, 0] = x
        arr[:, p, 1] = y
        arr[:, p, 2] = conf

    return arr.reshape(T, F)


print("interpolation v2 적용 중...")
X_interp = np.zeros_like(X_selected)
for i in range(len(X_selected)):
    X_interp[i] = interpolate_strong(X_selected[i])
print("보간 완료:", X_interp.shape)


# 8. confidence 제거 (x,y만)
def remove_confidence(X):
    N, T, F = X.shape
    P = F // 3
    coords = X.reshape(N, T, P, 3)[:, :, :, :2]   # (N,T,P,2)
    return coords.reshape(N, T, P*2)              # (N,T,36)

X_xy = remove_confidence(X_interp)
print("confidence 제거 완료:", X_xy.shape)


# 9. 단순 스케일링
X_xy /= 1000.0


# 10. Train/Test split (filtered 기준으로 라벨 생성)
labels_text = np.array([item["label"][0]["name"] for item in filtered])
encoder = LabelEncoder()
y = encoder.fit_transform(labels_text)

X_train, X_test, y_train, y_test = train_test_split(
    X_xy, y,
    test_size=0.2,
    shuffle=True,
    random_state=42,
    stratify=y
)

print("Train:", X_train.shape)
print("Test :", X_test.shape)
print("클래스 개수:", len(encoder.classes_))
print("전처리 파이프라인 완료 v")
# Out:
# 데이터 로드...
# 로드 완료. 총 세그먼트 수: 1757
# 제거할 라벨들: []
# 정제 후 세그먼트 수: 1757
# padding 중...
# raw_data shape: (1757, 106, 137, 3)
# reshape 완료: (1757, 106, 411)
# Mid-Hip 상대좌표 변환 중...
# Mid-Hip 완료: (1757, 106, 411)
# 핵심 keypoint 선택 중...
# 완료: (1757, 106, 54)
# interpolation v2 적용 중...
# 보간 완료: (1757, 106, 54)
# confidence 제거 완료: (1757, 106, 36)
# Train: (1405, 106, 36)
# Test : (352, 106, 36)
# 클래스 개수: 159
# 전처리 파이프라인 완료 v

# %%
# 0. 기본 import
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.layers import BatchNormalization, LayerNormalization, SpatialDropout1D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split


# 1. 전처리 결과 불러오기
X_final = X_xy.copy()
labels_final = y.copy()
num_classes = len(np.unique(labels_final))

# 2. Train / Val / Test split
X_train, X_test, y_train, y_test = train_test_split(
    X_final, labels_final,
    test_size=0.1, random_state=42, shuffle=True
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train,
    test_size=0.1, random_state=42, shuffle=True
)

# 3. class_weight 계산
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights_dict = {i: w for i, w in enumerate(class_weights)}

# 4. 최적화된 모델 (과적합 최소 + 정확도 최대)
seq_len = X_train.shape[1]
feature_dim = X_train.shape[2]

model = Sequential([
    tf.keras.Input(shape=(seq_len, feature_dim)),

    # 시퀀스 전체 regularization
    SpatialDropout1D(0.2),

    Bidirectional(LSTM(96, return_sequences=True)),
    LayerNormalization(),
    Dropout(0.35),

    Bidirectional(LSTM(64, return_sequences=False)),
    LayerNormalization(),
    Dropout(0.35),

    Dense(256, activation="relu"),
    BatchNormalization(),
    Dropout(0.4),

    Dense(num_classes, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# 5. 학습
es = EarlyStopping(
    monitor='val_loss', patience=8,
    restore_best_weights=True
)
rlr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-5
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=80,
    batch_size=16,
    class_weight=class_weights_dict,
    callbacks=[es, rlr],
    verbose=1
)

# 6. Test 평가
test_loss, test_acc = model.evaluate(X_test, y_test)
print(" Test Accuracy:", test_acc)
print(" Test Loss:", test_loss)

# 7. 학습 곡선 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

# 1) Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

# 2) Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ spatial_dropout1d               │ (None, 106, 36)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 106, 192)       │       102,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization             │ (None, 106, 192)       │           384 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 106, 192)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_1           │ (None, 128)            │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 159)            │        40,863 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 309,279 (1.18 MB)
#  Trainable params: 308,767 (1.18 MB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.0047 - loss: 5.8238 - val_accuracy: 0.0189 - val_loss: 5.0950 - learning_rate: 0.0010
# Epoch 2/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0116 - loss: 5.4790 - val_accuracy: 0.0126 - val_loss: 4.9435 - learning_rate: 0.0010
# Epoch 3/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.0191 - loss: 5.3061 - val_accuracy: 0.0126 - val_loss: 4.5932 - learning_rate: 0.0010
# Epoch 4/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.0246 - loss: 4.9785 - val_accuracy: 0.0377 - val_loss: 4.5289 - learning_rate: 0.0010
# Epoch 5/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0373 - loss: 4.7489 - val_accuracy: 0.0692 - val_loss: 4.3987 - learning_rate: 0.0010
# Epoch 6/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.0459 - loss: 4.7473 - val_accuracy: 0.0629 - val_loss: 4.4339 - learning_rate: 0.0010
# Epoch 7/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0282 - loss: 4.7684 - val_accuracy: 0.0629 - val_loss: 4.4701 - learning_rate: 0.0010
# Epoch 8/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0505 - loss: 4.5089 - val_accuracy: 0.0566 - val_loss: 4.2851 - learning_rate: 0.0010
# Epoch 9/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.0750 - loss: 4.2810 - val_accuracy: 0.0881 - val_loss: 4.0889 - learning_rate: 0.0010
# Epoch 10/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.0807 - loss: 4.0272 - val_accuracy: 0.1509 - val_loss: 3.8807 - learning_rate: 0.0010
# Epoch 11/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0995 - loss: 4.0543 - val_accuracy: 0.1384 - val_loss: 3.7147 - learning_rate: 0.0010
# Epoch 12/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0956 - loss: 3.9459 - val_accuracy: 0.1321 - val_loss: 3.7487 - learning_rate: 0.0010
# Epoch 13/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.1129 - loss: 3.8352 - val_accuracy: 0.1950 - val_loss: 3.5942 - learning_rate: 0.0010
# Epoch 14/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.1207 - loss: 3.7870 - val_accuracy: 0.2013 - val_loss: 3.6009 - learning_rate: 0.0010
# Epoch 15/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.1359 - loss: 3.5968 - val_accuracy: 0.1321 - val_loss: 3.7295 - learning_rate: 0.0010
# Epoch 16/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.1484 - loss: 3.5507 - val_accuracy: 0.2138 - val_loss: 3.4516 - learning_rate: 0.0010
# Epoch 17/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.1675 - loss: 3.5109 - val_accuracy: 0.2390 - val_loss: 3.3146 - learning_rate: 0.0010
# Epoch 18/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.2160 - loss: 3.3087 - val_accuracy: 0.2327 - val_loss: 3.4181 - learning_rate: 0.0010
# Epoch 19/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.2013 - loss: 3.3405 - val_accuracy: 0.3145 - val_loss: 3.1531 - learning_rate: 0.0010
# Epoch 20/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.2523 - loss: 3.1049 - val_accuracy: 0.2075 - val_loss: 3.4201 - learning_rate: 0.0010
# Epoch 21/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2122 - loss: 3.2391 - val_accuracy: 0.2327 - val_loss: 3.1531 - learning_rate: 0.0010
# Epoch 22/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2508 - loss: 3.0869 - val_accuracy: 0.3082 - val_loss: 2.9377 - learning_rate: 0.0010
# Epoch 23/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.2442 - loss: 3.0935 - val_accuracy: 0.3585 - val_loss: 2.9747 - learning_rate: 0.0010
# Epoch 24/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.2721 - loss: 2.9095 - val_accuracy: 0.3648 - val_loss: 2.8433 - learning_rate: 0.0010
# Epoch 25/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.2891 - loss: 2.8401 - val_accuracy: 0.3711 - val_loss: 2.7325 - learning_rate: 0.0010
# Epoch 26/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3304 - loss: 2.7709 - val_accuracy: 0.3899 - val_loss: 2.8216 - learning_rate: 0.0010
# Epoch 27/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.3198 - loss: 2.7325 - val_accuracy: 0.4214 - val_loss: 2.6855 - learning_rate: 0.0010
# Epoch 28/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.3492 - loss: 2.5871 - val_accuracy: 0.3899 - val_loss: 2.7473 - learning_rate: 0.0010
# Epoch 29/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.3665 - loss: 2.4967 - val_accuracy: 0.4403 - val_loss: 2.6500 - learning_rate: 0.0010
# Epoch 30/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3702 - loss: 2.5311 - val_accuracy: 0.4654 - val_loss: 2.5498 - learning_rate: 0.0010
# Epoch 31/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.3831 - loss: 2.4481 - val_accuracy: 0.5031 - val_loss: 2.5311 - learning_rate: 0.0010
# Epoch 32/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.3947 - loss: 2.4333 - val_accuracy: 0.4214 - val_loss: 2.4986 - learning_rate: 0.0010
# Epoch 33/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.3847 - loss: 2.3886 - val_accuracy: 0.4654 - val_loss: 2.5438 - learning_rate: 0.0010
# Epoch 34/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.4415 - loss: 2.2678 - val_accuracy: 0.4340 - val_loss: 2.4835 - learning_rate: 0.0010
# Epoch 35/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4185 - loss: 2.3033 - val_accuracy: 0.4906 - val_loss: 2.4082 - learning_rate: 0.0010
# Epoch 36/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4141 - loss: 2.2546 - val_accuracy: 0.4906 - val_loss: 2.4745 - learning_rate: 0.0010
# Epoch 37/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.4350 - loss: 2.3171 - val_accuracy: 0.4906 - val_loss: 2.3376 - learning_rate: 0.0010
# Epoch 38/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4334 - loss: 2.1608 - val_accuracy: 0.4843 - val_loss: 2.3854 - learning_rate: 0.0010
# Epoch 39/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4469 - loss: 2.1192 - val_accuracy: 0.4843 - val_loss: 2.4648 - learning_rate: 0.0010
# Epoch 40/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4427 - loss: 2.0895 - val_accuracy: 0.5535 - val_loss: 2.2325 - learning_rate: 0.0010
# Epoch 41/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4709 - loss: 1.9645 - val_accuracy: 0.5660 - val_loss: 2.3373 - learning_rate: 0.0010
# Epoch 42/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4610 - loss: 2.0058 - val_accuracy: 0.5031 - val_loss: 2.3665 - learning_rate: 0.0010
# Epoch 43/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.4329 - loss: 2.1230 - val_accuracy: 0.5786 - val_loss: 2.1795 - learning_rate: 0.0010
# Epoch 44/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5304 - loss: 1.7789 - val_accuracy: 0.5975 - val_loss: 2.2558 - learning_rate: 0.0010
# Epoch 45/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4749 - loss: 1.9862 - val_accuracy: 0.5409 - val_loss: 2.1765 - learning_rate: 0.0010
# Epoch 46/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4825 - loss: 1.8349 - val_accuracy: 0.6038 - val_loss: 2.1400 - learning_rate: 0.0010
# Epoch 47/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5053 - loss: 1.8738 - val_accuracy: 0.5786 - val_loss: 2.1659 - learning_rate: 0.0010
# Epoch 48/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5014 - loss: 1.7862 - val_accuracy: 0.6101 - val_loss: 2.1495 - learning_rate: 0.0010
# Epoch 49/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.5459 - loss: 1.7173 - val_accuracy: 0.5597 - val_loss: 2.1185 - learning_rate: 0.0010
# Epoch 50/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5572 - loss: 1.6780 - val_accuracy: 0.5597 - val_loss: 2.2541 - learning_rate: 0.0010
# Epoch 51/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5112 - loss: 1.7721 - val_accuracy: 0.6038 - val_loss: 2.0911 - learning_rate: 0.0010
# Epoch 52/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5431 - loss: 1.6680 - val_accuracy: 0.6226 - val_loss: 2.0119 - learning_rate: 0.0010
# Epoch 53/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5230 - loss: 1.7386 - val_accuracy: 0.5912 - val_loss: 2.1275 - learning_rate: 0.0010
# Epoch 54/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5784 - loss: 1.5973 - val_accuracy: 0.5912 - val_loss: 2.0595 - learning_rate: 0.0010
# Epoch 55/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.5478 - loss: 1.6576 - val_accuracy: 0.6038 - val_loss: 2.1872 - learning_rate: 0.0010
# Epoch 56/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5399 - loss: 1.6817 - val_accuracy: 0.6289 - val_loss: 2.0539 - learning_rate: 5.0000e-04
# Epoch 57/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5617 - loss: 1.6446 - val_accuracy: 0.6164 - val_loss: 2.0435 - learning_rate: 5.0000e-04
# Epoch 58/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5953 - loss: 1.4425 - val_accuracy: 0.6226 - val_loss: 2.0522 - learning_rate: 5.0000e-04
# Epoch 59/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.6121 - loss: 1.3580 - val_accuracy: 0.6164 - val_loss: 2.0095 - learning_rate: 2.5000e-04
# Epoch 60/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6322 - loss: 1.3747 - val_accuracy: 0.6289 - val_loss: 2.0153 - learning_rate: 2.5000e-04
# Epoch 61/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6709 - loss: 1.2748 - val_accuracy: 0.6415 - val_loss: 2.0254 - learning_rate: 2.5000e-04
# Epoch 62/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6403 - loss: 1.2396 - val_accuracy: 0.6289 - val_loss: 2.0420 - learning_rate: 2.5000e-04
# Epoch 63/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6211 - loss: 1.3315 - val_accuracy: 0.6604 - val_loss: 1.9776 - learning_rate: 1.2500e-04
# Epoch 64/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6194 - loss: 1.2763 - val_accuracy: 0.6478 - val_loss: 1.9866 - learning_rate: 1.2500e-04
# Epoch 65/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6614 - loss: 1.2695 - val_accuracy: 0.6226 - val_loss: 1.9766 - learning_rate: 1.2500e-04
# Epoch 66/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6430 - loss: 1.2343 - val_accuracy: 0.6478 - val_loss: 1.9642 - learning_rate: 1.2500e-04
# Epoch 67/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6576 - loss: 1.1967 - val_accuracy: 0.6478 - val_loss: 1.9574 - learning_rate: 1.2500e-04
# Epoch 68/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6263 - loss: 1.2622 - val_accuracy: 0.6541 - val_loss: 1.9826 - learning_rate: 1.2500e-04
# Epoch 69/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.6467 - loss: 1.1991 - val_accuracy: 0.6541 - val_loss: 1.9699 - learning_rate: 1.2500e-04
# Epoch 70/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6535 - loss: 1.2158 - val_accuracy: 0.6352 - val_loss: 1.9725 - learning_rate: 1.2500e-04
# Epoch 71/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6694 - loss: 1.2056 - val_accuracy: 0.6478 - val_loss: 1.9684 - learning_rate: 6.2500e-05
# Epoch 72/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6546 - loss: 1.2248 - val_accuracy: 0.6478 - val_loss: 1.9699 - learning_rate: 6.2500e-05
# Epoch 73/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6430 - loss: 1.2434 - val_accuracy: 0.6352 - val_loss: 1.9728 - learning_rate: 6.2500e-05
# Epoch 74/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.6618 - loss: 1.2182 - val_accuracy: 0.6415 - val_loss: 1.9711 - learning_rate: 3.1250e-05
# Epoch 75/80
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6461 - loss: 1.2276 - val_accuracy: 0.6415 - val_loss: 1.9674 - learning_rate: 3.1250e-05
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7189 - loss: 1.6584
#  Test Accuracy: 0.7386363744735718
#  Test Loss: 1.5988681316375732

# %%
# 환경 초기화 & 기본 설정
import gc
import random
import numpy as np
import json
import tensorflow as tf
import matplotlib.pyplot as plt

from collections import Counter
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Masking, Bidirectional, GRU,
    Dense, Dropout, LayerNormalization,
    Attention
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# 메모리 / 세션 초기화
gc.collect()
tf.keras.backend.clear_session()

# 재현성
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

print("Environment reset complete.")


# 데이터 로드 & 라벨 정제
file_path = '/content/drive/MyDrive/sign_data/processed/merged_dataset.json'

with open(file_path, 'r', encoding='utf-8') as f:
    data_json = json.load(f)

print("원본 샘플 수:", len(data_json))

# 필수 키 체크
required_keys = {"frames", "label"}
issues = [i for i, item in enumerate(data_json) if not required_keys.issubset(item.keys())]
print("구조 이상 샘플 수:", len(issues))

# 라벨 오타 → 표준 라벨 매핑
label_fix_map = {
    "꽈베기": "꽈배기",
    "배추국": "배춧국",
    "된장찌게": "된장찌개",
}

for item in data_json:
    label = item['label'][0]['name']
    if label in label_fix_map:
        item['label'][0]['name'] = label_fix_map[label]

# 라벨 분포 확인
labels_all = [item['label'][0]['name'] for item in data_json]
label_counts_all = Counter(labels_all)
print("원본 클래스 개수:", len(label_counts_all))

# 샘플 2개 미만 라벨 제거
remove_labels = [k for k, v in label_counts_all.items() if v < 2]
filtered_data = [item for item in data_json if item['label'][0]['name'] not in remove_labels]

print("라벨 정제 완료!")
print("정제 후 샘플 수:", len(filtered_data))
print("제거된 라벨:", remove_labels)

# 정제 후 라벨 분포
labels_filtered = [item['label'][0]['name'] for item in filtered_data]
label_counts_filtered = Counter(labels_filtered)
print("정제 후 클래스 개수:", len(label_counts_filtered))
print("상위 10개:", label_counts_filtered.most_common(10))
print("샘플수 2 미만 여부:", [k for k,v in label_counts_filtered.items() if v < 2])

# 각 샘플 길이
seq_lengths_all = np.array([len(item['frames']) for item in filtered_data])
print("최소 길이:", seq_lengths_all.min())
print("최대 길이:", seq_lengths_all.max())
print("평균 길이:", seq_lengths_all.mean())

plt.hist(seq_lengths_all, bins=30)
plt.title("Sequence Length Distribution (filtered)")
plt.show()


# frames padding → (N, T, 137, 3)
def pad_frames(dataset):
    sequences = [item["frames"] for item in dataset]
    padded = pad_sequences(sequences, padding='post', dtype='float32')
    print("Padding 완료:", padded.shape)
    return padded

X_raw = pad_frames(filtered_data)   # (N, T, 137, 3)
N, T_max, P, C = X_raw.shape
print("X_raw shape:", X_raw.shape)


# Mid-Hip 기준 상대 좌표 변환

def normalize_midhip(X):

    X = X.copy()
    N, T, P, C = X.shape

    REF_INDEX = 0  # Mid-Hip
    ref_xy = X[:, :, REF_INDEX, :2]         # (N,T,2)
    ref_xy = ref_xy[:, :, None, :]          # (N,T,1,2)

    X[:, :, :, :2] -= ref_xy                # x,y → 상대좌표

    print("Mid-Hip Normalize 완료:", X.shape)
    return X

X_norm_mhip = normalize_midhip(X_raw)


# 포즈 + 양손 스켈레톤 XY만 추출 → (N, T, D)
# (몸 25 + 왼손 21 + 오른손 21 = 67 포인트)
def extract_xy_features(X):

    N, T, P, C = X.shape

    pose = X[:, :, :25, :]      # body
    lh   = X[:, :, 25:46, :]    # left hand
    rh   = X[:, :, 46:67, :]    # right hand

    full = np.concatenate([pose, lh, rh], axis=2)  # (N,T,67,3)

    xy = full[:, :, :, :2]      # x,y만
    final = xy.reshape(N, T, -1)

    print("🧬 Full Skeleton XY Features:", final.shape)
    return final

X_xy_all = extract_xy_features(X_norm_mhip)   # (N, T, 134)


# 라벨 인코딩 & Train/Test Split (stratify)
encoder = LabelEncoder()
y_all = encoder.fit_transform(labels_filtered)
num_classes = len(np.unique(y_all))
print("클래스 수:", num_classes)

idx_all = np.arange(len(y_all))
idx_train, idx_test = train_test_split(
    idx_all,
    test_size=0.2,
    shuffle=True,
    stratify=y_all,
    random_state=42
)

X_train_raw = X_xy_all[idx_train]
X_test_raw  = X_xy_all[idx_test]
y_train = y_all[idx_train]
y_test  = y_all[idx_test]
seq_train = seq_lengths_all[idx_train]
seq_test  = seq_lengths_all[idx_test]

print("Train Raw:", X_train_raw.shape)
print("Test  Raw:", X_test_raw.shape)


# Z-Score 정규화 (Train 유효 프레임 기준)
def compute_mean_std_nonpad(X, seq_lengths):
    """
    X : (N,T,D), seq_lengths : (N,)
    유효 프레임(t < seq_len)에 대해서만 mean, std 계산
    """
    N, T, D = X.shape
    total_frames = int(seq_lengths.sum())

    s = np.zeros(D, dtype=np.float64)
    ss = np.zeros(D, dtype=np.float64)

    for i in range(N):
        L = seq_lengths[i]
        if L == 0:
            continue
        Xi = X[i, :L, :]       # (L,D)
        s  += Xi.sum(axis=0)
        ss += (Xi ** 2).sum(axis=0)

    mean = s / total_frames
    var  = ss / total_frames - mean**2
    std  = np.sqrt(var + 1e-6)

    return mean.astype(np.float32), std.astype(np.float32)

mean_vec, std_vec = compute_mean_std_nonpad(X_train_raw, seq_train)
print("mean shape:", mean_vec.shape, "std shape:", std_vec.shape)

def apply_norm_nonpad(X, seq_lengths, mean, std):

    Xn = np.zeros_like(X, dtype=np.float32)
    N, T, D = X.shape

    for i in range(N):
        L = seq_lengths[i]
        if L == 0:
            continue
        Xi = X[i, :L, :]
        Xn[i, :L, :] = (Xi - mean) / std
        # 나머지 [L:]는 0 (패딩)

    return Xn

X_train = apply_norm_nonpad(X_train_raw, seq_train, mean_vec, std_vec)
X_test  = apply_norm_nonpad(X_test_raw,  seq_test,  mean_vec, std_vec)

print("Normalization 완료.")
print("Train:", X_train.shape)
print("Test :", X_test.shape)


# 데이터 증강 (Train만)
# - Gaussian Noise
# - Frame Dropout
def augment_data_v2(x, seq_len,
                    noise_std=0.01,
                    dropout_rate=0.05,
                    shift_range=0.05,
                    scale_range=0.1):

    T_max, D = x.shape
    L = int(seq_len)

    if L <= 0:
        return x.copy()

    x_out = x.copy()
    x_valid = x_out[:L]

    # 1) Gaussian noise
    x_valid += np.random.normal(0, noise_std, size=x_valid.shape).astype(x_valid.dtype)

    # 2) global shift (전체 좌표 평행이동)
    shift = np.random.uniform(-shift_range, shift_range)
    x_valid += shift

    # 3) global scale (몸 크기/카메라 거리 변화)
    scale = 1.0 + np.random.uniform(-scale_range, scale_range)
    x_valid *= scale

    # 4) frame dropout (완전 0이 아니라 약하게 줄이기)
    drop_mask = np.random.rand(L) < dropout_rate
    if drop_mask.any():
        x_valid[drop_mask] *= 0.1  # 에너지만 줄이고 0은 피함

    x_out[:L] = x_valid
    return x_out

X_aug_list = []
y_aug_list = []

for i in range(len(X_train)):
    X_aug_list.append(augment_data_v2(X_train[i], seq_train[i]))
    y_aug_list.append(y_train[i])

X_augmented = np.stack(X_aug_list)
y_augmented = np.array(y_aug_list)

X_train2 = np.concatenate([X_train, X_augmented], axis=0)
y_train2 = np.concatenate([y_train, y_augmented], axis=0)

print("원본 Train:", X_train.shape, len(y_train))
print("증강 포함 Train:", X_train2.shape, len(y_train2))

from tensorflow.keras.layers import MultiHeadAttention

def build_hybrid_model(input_dim, num_classes):
    inputs = Input(shape=(None, input_dim))

    # 0) Masking (오른쪽 패딩 0만 마스크)
    x = Masking(mask_value=0.0)(inputs)

    # 1) BiGRU로 1차 시퀀스 인코딩
    x = Bidirectional(
        GRU(
            64,
            return_sequences=True,
            dropout=0.2,
            reset_after=False,
            use_cudnn=False
        )
    )(x)

    # 2) Transformer Encoder 블록 1개
    # - Multi-Head Self-Attention
    attn_out = MultiHeadAttention(num_heads=4, key_dim=32)(x, x)
    x = LayerNormalization()(x + attn_out)

    # - Position-wise Feed Forward
    ff = Dense(128, activation='relu')(x)
    ff = Dropout(0.3)(ff)
    x = LayerNormalization()(x + ff)

    # 3) GRU로 요약
    x = GRU(
        32,
        dropout=0.3,
        reset_after=False,
        use_cudnn=False
    )(x)

    # 4) Dense head
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)

    outputs = Dense(num_classes, activation="softmax")(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=Adam(learning_rate=3e-4),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model


# Class Weight 적용
from sklearn.utils.class_weight import compute_class_weight

# class weight 재계산 (증강 포함 y_train2 기준)
class_weights = compute_class_weight(
    "balanced",
    classes=np.unique(y_train2),
    y=y_train2
)
class_weights = dict(enumerate(class_weights))
print("\n Class Weights:", class_weights)


# 학습
model = build_hybrid_model(X_train2.shape[-1], num_classes)
model.summary()

callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, verbose=1)
]

history = model.fit(
    X_train2, y_train2,
    validation_split=0.2,
    epochs=250,
    batch_size=32,
    callbacks=callbacks,
    class_weight=class_weights,
    verbose=1
)

def plot_history(history, title="Model"):
    plt.figure(figsize=(12,5))

    # Loss
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{title} - Loss')
    plt.legend()

    # Accuracy
    plt.subplot(1,2,2)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title(f'{title} - Accuracy')
    plt.legend()

    plt.show()


def print_results(history):
    best_epoch = int(np.argmin(history.history['val_loss']) + 1)
    print(f"\n Best Epoch: {best_epoch}")
    print(f" Final Train Accuracy: {history.history['accuracy'][-1]:.4f}")
    print(f" Best Validation Accuracy: {history.history['val_accuracy'][best_epoch-1]:.4f}")
    print(f" Final Train Loss: {history.history['loss'][-1]:.4f}")
    print(f" Best Validation Loss: {history.history['val_loss'][best_epoch-1]:.4f}")


# 결과 출력
plot_history(history)
print_results(history)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\n Test Loss: {test_loss:.4f},  Test Accuracy: {test_acc:.4f}")
# Out:
# Environment reset complete.
# 원본 샘플 수: 1757
# 구조 이상 샘플 수: 0
# 원본 클래스 개수: 160
# 라벨 정제 완료!
# 정제 후 샘플 수: 1756
# 제거된 라벨: ['결승전1']
# 정제 후 클래스 개수: 159
# 상위 10개: [('음주운전', 22), ('백설기', 12), ('체감', 12), ('고민', 11), ('수어', 11), ('뻔뻔', 11), ('눈', 11), ('발가락', 11), ('슬프다', 11), ('독신', 11)]
# 샘플수 2 미만 여부: []
# 최소 길이: 15
# 최대 길이: 106
# 평균 길이: 54.87072892938497
# Padding 완료: (1756, 106, 137, 3)
# X_raw shape: (1756, 106, 137, 3)
# Mid-Hip Normalize 완료: (1756, 106, 137, 3)
# 🧬 Full Skeleton XY Features: (1756, 106, 134)
# 클래스 수: 159
# Train Raw: (1404, 106, 134)
# Test  Raw: (352, 106, 134)
# mean shape: (134,) std shape: (134,)
# Normalization 완료.
# Train: (1404, 106, 134)
# Test : (352, 106, 134)
# 원본 Train: (1404, 106, 134) 1404
# 증강 포함 Train: (2808, 106, 134) 2808
#
#  Class Weights: {0: np.float64(0.9811320754716981), 1: np.float64(1.1037735849056605), 2: np.float64(1.1037735849056605), 3: np.float64(0.9811320754716981), 4: np.float64(0.9811320754716981), 5: np.float64(0.9811320754716981), 6: np.float64(0.9811320754716981), 7: np.float64(1.1037735849056605), 8: np.float64(1.1037735849056605), 9: np.float64(0.9811320754716981), 10: np.float64(0.9811320754716981), 11: np.float64(0.9811320754716981), 12: np.float64(0.9811320754716981), 13: np.float64(0.9811320754716981), 14: np.float64(0.9811320754716981), 15: np.float64(0.9811320754716981), 16: np.float64(1.1037735849056605), 17: np.float64(0.9811320754716981), 18: np.float64(0.9811320754716981), 19: np.float64(0.9811320754716981), 20: np.float64(0.9811320754716981), 21: np.float64(0.9811320754716981), 22: np.float64(1.1037735849056605), 23: np.float64(1.1037735849056605), 24: np.float64(0.9811320754716981), 25: np.float64(0.9811320754716981), 26: np.float64(0.9811320754716981), 27: np.float64(0.9811320754716981), 28: np.float64(0.9811320754716981), 29: np.float64(0.9811320754716981), 30: np.float64(0.9811320754716981), 31: np.float64(0.9811320754716981), 32: np.float64(0.9811320754716981), 33: np.float64(0.9811320754716981), 34: np.float64(0.9811320754716981), 35: np.float64(0.9811320754716981), 36: np.float64(0.9811320754716981), 37: np.float64(0.9811320754716981), 38: np.float64(0.9811320754716981), 39: np.float64(1.1037735849056605), 40: np.float64(0.9811320754716981), 41: np.float64(0.9811320754716981), 42: np.float64(0.9811320754716981), 43: np.float64(0.9811320754716981), 44: np.float64(0.9811320754716981), 45: np.float64(0.9811320754716981), 46: np.float64(0.9811320754716981), 47: np.float64(0.9811320754716981), 48: np.float64(0.9811320754716981), 49: np.float64(0.9811320754716981), 50: np.float64(1.1037735849056605), 51: np.float64(0.9811320754716981), 52: np.float64(1.1037735849056605), 53: np.float64(0.9811320754716981), 54: np.float64(1.1037735849056605), 55: np.float64(0.9811320754716981), 56: np.float64(1.1037735849056605), 57: np.float64(0.9811320754716981), 58: np.float64(0.9811320754716981), 59: np.float64(0.9811320754716981), 60: np.float64(1.1037735849056605), 61: np.float64(1.1037735849056605), 62: np.float64(1.1037735849056605), 63: np.float64(0.9811320754716981), 64: np.float64(0.9811320754716981), 65: np.float64(0.9811320754716981), 66: np.float64(0.9811320754716981), 67: np.float64(1.1037735849056605), 68: np.float64(0.9811320754716981), 69: np.float64(0.9811320754716981), 70: np.float64(0.9811320754716981), 71: np.float64(0.9811320754716981), 72: np.float64(0.9811320754716981), 73: np.float64(0.9811320754716981), 74: np.float64(0.9811320754716981), 75: np.float64(0.9811320754716981), 76: np.float64(0.9811320754716981), 77: np.float64(0.9811320754716981), 78: np.float64(1.1037735849056605), 79: np.float64(0.9811320754716981), 80: np.float64(0.9811320754716981), 81: np.float64(0.9811320754716981), 82: np.float64(0.9811320754716981), 83: np.float64(0.9811320754716981), 84: np.float64(0.9811320754716981), 85: np.float64(0.9811320754716981), 86: np.float64(0.9811320754716981), 87: np.float64(0.9811320754716981), 88: np.float64(0.9811320754716981), 89: np.float64(0.9811320754716981), 90: np.float64(0.9811320754716981), 91: np.float64(1.1037735849056605), 92: np.float64(1.1037735849056605), 93: np.float64(0.9811320754716981), 94: np.float64(0.9811320754716981), 95: np.float64(0.9811320754716981), 96: np.float64(0.9811320754716981), 97: np.float64(0.9811320754716981), 98: np.float64(0.9811320754716981), 99: np.float64(0.9811320754716981), 100: np.float64(0.9811320754716981), 101: np.float64(0.9811320754716981), 102: np.float64(1.1037735849056605), 103: np.float64(0.9811320754716981), 104: np.float64(1.1037735849056605), 105: np.float64(1.1037735849056605), 106: np.float64(0.9811320754716981), 107: np.float64(1.1037735849056605), 108: np.float64(1.1037735849056605), 109: np.float64(0.9811320754716981), 110: np.float64(0.98113 ...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None, 134) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, None, 134) │          0 │ input_layer[0][0] │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, None, 134) │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, None)      │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, None, 128) │     76,416 │ masking[0][0],    │
# │ (Bidirectional)     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, None, 128) │     66,048 │ bidirectional[0]… │
# │ (MultiHeadAttentio… │                   │            │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, None, 128) │          0 │ bidirectional[0]… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, None, 128) │        256 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None, 128) │     16,512 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None, 128) │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, None, 128) │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, None, 128) │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_1 (GRU)         │ (None, 32)        │     15,456 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      2,112 │ gru_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 159)       │     10,335 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 187,391 (732.00 KB)
#  Trainable params: 187,391 (732.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 34s 214ms/step - accuracy: 0.0069 - loss: 5.1164 - val_accuracy: 0.0160 - val_loss: 5.0129 - learning_rate: 3.0000e-04
# Epoch 2/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.0159 - loss: 5.0268 - val_accuracy: 0.0267 - val_loss: 4.9364 - learning_rate: 3.0000e-04
# Epoch 3/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0184 - loss: 4.9472 - val_accuracy: 0.0391 - val_loss: 4.8530 - learning_rate: 3.0000e-04
# Epoch 4/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0321 - loss: 4.8466 - val_accuracy: 0.0391 - val_loss: 4.7487 - learning_rate: 3.0000e-04
# Epoch 5/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.0369 - loss: 4.7621 - val_accuracy: 0.0623 - val_loss: 4.6377 - learning_rate: 3.0000e-04
# Epoch 6/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.0354 - loss: 4.6907 - val_accuracy: 0.0712 - val_loss: 4.5203 - learning_rate: 3.0000e-04
# Epoch 7/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0459 - loss: 4.5649 - val_accuracy: 0.0907 - val_loss: 4.4050 - learning_rate: 3.0000e-04
# Epoch 8/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0663 - loss: 4.4382 - val_accuracy: 0.0996 - val_loss: 4.2890 - learning_rate: 3.0000e-04
# Epoch 9/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.0728 - loss: 4.3692 - val_accuracy: 0.1228 - val_loss: 4.1773 - learning_rate: 3.0000e-04
# Epoch 10/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.0756 - loss: 4.2527 - val_accuracy: 0.1459 - val_loss: 4.0745 - learning_rate: 3.0000e-04
# Epoch 11/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0812 - loss: 4.1722 - val_accuracy: 0.1477 - val_loss: 3.9663 - learning_rate: 3.0000e-04
# Epoch 12/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0902 - loss: 4.0784 - val_accuracy: 0.1779 - val_loss: 3.8714 - learning_rate: 3.0000e-04
# Epoch 13/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.1029 - loss: 4.0307 - val_accuracy: 0.1726 - val_loss: 3.7726 - learning_rate: 3.0000e-04
# Epoch 14/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.1164 - loss: 3.9485 - val_accuracy: 0.1957 - val_loss: 3.6970 - learning_rate: 3.0000e-04
# Epoch 15/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.1257 - loss: 3.8475 - val_accuracy: 0.2278 - val_loss: 3.5970 - learning_rate: 3.0000e-04
# Epoch 16/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.1342 - loss: 3.8007 - val_accuracy: 0.2544 - val_loss: 3.5190 - learning_rate: 3.0000e-04
# Epoch 17/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.1535 - loss: 3.6943 - val_accuracy: 0.2687 - val_loss: 3.4343 - learning_rate: 3.0000e-04
# Epoch 18/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.1528 - loss: 3.6592 - val_accuracy: 0.2847 - val_loss: 3.3394 - learning_rate: 3.0000e-04
# Epoch 19/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.1485 - loss: 3.6028 - val_accuracy: 0.2900 - val_loss: 3.2714 - learning_rate: 3.0000e-04
# Epoch 20/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.1580 - loss: 3.5195 - val_accuracy: 0.3238 - val_loss: 3.1865 - learning_rate: 3.0000e-04
# Epoch 21/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.1866 - loss: 3.4374 - val_accuracy: 0.3185 - val_loss: 3.1136 - learning_rate: 3.0000e-04
# Epoch 22/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.1827 - loss: 3.3890 - val_accuracy: 0.3452 - val_loss: 3.0385 - learning_rate: 3.0000e-04
# Epoch 23/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.1817 - loss: 3.3549 - val_accuracy: 0.3559 - val_loss: 2.9627 - learning_rate: 3.0000e-04
# Epoch 24/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.1945 - loss: 3.3162 - val_accuracy: 0.3772 - val_loss: 2.9062 - learning_rate: 3.0000e-04
# Epoch 25/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.1878 - loss: 3.2361 - val_accuracy: 0.4146 - val_loss: 2.8295 - learning_rate: 3.0000e-04
# Epoch 26/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.2042 - loss: 3.2122 - val_accuracy: 0.4110 - val_loss: 2.7588 - learning_rate: 3.0000e-04
# Epoch 27/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.2294 - loss: 3.1457 - val_accuracy: 0.4448 - val_loss: 2.7196 - learning_rate: 3.0000e-04
# Epoch 28/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.2395 - loss: 3.0943 - val_accuracy: 0.4537 - val_loss: 2.6378 - learning_rate: 3.0000e-04
# Epoch 29/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.2716 - loss: 2.9962 - val_accuracy: 0.4537 - val_loss: 2.5961 - learning_rate: 3.0000e-04
# Epoch 30/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.2484 - loss: 2.9748 - val_accuracy: 0.4893 - val_loss: 2.5250 - learning_rate: 3.0000e-04
# Epoch 31/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.2745 - loss: 2.9210 - val_accuracy: 0.4858 - val_loss: 2.4718 - learning_rate: 3.0000e-04
# Epoch 32/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.2509 - loss: 2.9000 - val_accuracy: 0.4982 - val_loss: 2.4206 - learning_rate: 3.0000e-04
# Epoch 33/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.2799 - loss: 2.8060 - val_accuracy: 0.4964 - val_loss: 2.3704 - learning_rate: 3.0000e-04
# Epoch 34/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3098 - loss: 2.7900 - val_accuracy: 0.5427 - val_loss: 2.3044 - learning_rate: 3.0000e-04
# Epoch 35/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.2913 - loss: 2.7382 - val_accuracy: 0.5463 - val_loss: 2.2549 - learning_rate: 3.0000e-04
# Epoch 36/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.3059 - loss: 2.6880 - val_accuracy: 0.5445 - val_loss: 2.2077 - learning_rate: 3.0000e-04
# Epoch 37/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.3134 - loss: 2.6977 - val_accuracy: 0.5783 - val_loss: 2.1580 - learning_rate: 3.0000e-04
# Epoch 38/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3382 - loss: 2.5865 - val_accuracy: 0.5783 - val_loss: 2.1113 - learning_rate: 3.0000e-04
# Epoch 39/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.3236 - loss: 2.5987 - val_accuracy: 0.5765 - val_loss: 2.0647 - learning_rate: 3.0000e-04
# Epoch 40/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.3328 - loss: 2.5374 - val_accuracy: 0.6263 - val_loss: 2.0152 - learning_rate: 3.0000e-04
# Epoch 41/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.3589 - loss: 2.4948 - val_accuracy: 0.6210 - val_loss: 1.9708 - learning_rate: 3.0000e-04
# Epoch 42/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3733 - loss: 2.4382 - val_accuracy: 0.6068 - val_loss: 1.9267 - learning_rate: 3.0000e-04
# Epoch 43/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.3706 - loss: 2.3929 - val_accuracy: 0.6157 - val_loss: 1.9199 - learning_rate: 3.0000e-04
# Epoch 44/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.3653 - loss: 2.4243 - val_accuracy: 0.6335 - val_loss: 1.8688 - learning_rate: 3.0000e-04
# Epoch 45/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3875 - loss: 2.3606 - val_accuracy: 0.6352 - val_loss: 1.8336 - learning_rate: 3.0000e-04
# Epoch 46/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3840 - loss: 2.3372 - val_accuracy: 0.6512 - val_loss: 1.7625 - learning_rate: 3.0000e-04
# Epoch 47/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.3862 - loss: 2.3224 - val_accuracy: 0.6637 - val_loss: 1.7220 - learning_rate: 3.0000e-04
# Epoch 48/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.4077 - loss: 2.2596 - val_accuracy: 0.6601 - val_loss: 1.6947 - learning_rate: 3.0000e-04
# Epoch 49/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4031 - loss: 2.2762 - val_accuracy: 0.6779 - val_loss: 1.6744 - learning_rate: 3.0000e-04
# Epoch 50/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4225 - loss: 2.1740 - val_accuracy: 0.6815 - val_loss: 1.6290 - learning_rate: 3.0000e-04
# Epoch 51/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.4359 - loss: 2.1602 - val_accuracy: 0.7028 - val_loss: 1.5775 - learning_rate: 3.0000e-04
# Epoch 52/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4382 - loss: 2.1625 - val_accuracy: 0.6815 - val_loss: 1.5904 - learning_rate: 3.0000e-04
# Epoch 53/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4232 - loss: 2.1577 - val_accuracy: 0.7153 - val_loss: 1.5146 - learning_rate: 3.0000e-04
# Epoch 54/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4432 - loss: 2.1055 - val_accuracy: 0.7153 - val_loss: 1.4994 - learning_rate: 3.0000e-04
# Epoch 55/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4474 - loss: 2.0754 - val_accuracy: 0.7206 - val_loss: 1.4757 - learning_rate: 3.0000e-04
# Epoch 56/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4511 - loss: 2.0195 - val_accuracy: 0.7491 - val_loss: 1.4153 - learning_rate: 3.0000e-04
# Epoch 57/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.4645 - loss: 2.0011 - val_accuracy: 0.7313 - val_loss: 1.3931 - learning_rate: 3.0000e-04
# Epoch 58/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.4509 - loss: 2.0163 - val_accuracy: 0.7313 - val_loss: 1.3976 - learning_rate: 3.0000e-04
# Epoch 59/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4723 - loss: 1.9438 - val_accuracy: 0.7438 - val_loss: 1.3593 - learning_rate: 3.0000e-04
# Epoch 60/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4660 - loss: 1.9440 - val_accuracy: 0.7527 - val_loss: 1.3388 - learning_rate: 3.0000e-04
# Epoch 61/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4894 - loss: 1.9012 - val_accuracy: 0.7651 - val_loss: 1.3087 - learning_rate: 3.0000e-04
# Epoch 62/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4722 - loss: 1.9332 - val_accuracy: 0.7740 - val_loss: 1.2696 - learning_rate: 3.0000e-04
# Epoch 63/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.5174 - loss: 1.8174 - val_accuracy: 0.7722 - val_loss: 1.2550 - learning_rate: 3.0000e-04
# Epoch 64/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.4949 - loss: 1.8243 - val_accuracy: 0.7758 - val_loss: 1.2418 - learning_rate: 3.0000e-04
# Epoch 65/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.4936 - loss: 1.8479 - val_accuracy: 0.7865 - val_loss: 1.2211 - learning_rate: 3.0000e-04
# Epoch 66/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5080 - loss: 1.8049 - val_accuracy: 0.7829 - val_loss: 1.1960 - learning_rate: 3.0000e-04
# Epoch 67/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.5187 - loss: 1.7540 - val_accuracy: 0.7669 - val_loss: 1.1897 - learning_rate: 3.0000e-04
# Epoch 68/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5213 - loss: 1.7548 - val_accuracy: 0.7936 - val_loss: 1.1622 - learning_rate: 3.0000e-04
# Epoch 69/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.5229 - loss: 1.7114 - val_accuracy: 0.8078 - val_loss: 1.1436 - learning_rate: 3.0000e-04
# Epoch 70/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.5151 - loss: 1.7221 - val_accuracy: 0.7900 - val_loss: 1.0877 - learning_rate: 3.0000e-04
# Epoch 71/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5539 - loss: 1.6448 - val_accuracy: 0.7936 - val_loss: 1.0760 - learning_rate: 3.0000e-04
# Epoch 72/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5856 - loss: 1.5872 - val_accuracy: 0.7972 - val_loss: 1.0609 - learning_rate: 3.0000e-04
# Epoch 73/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5431 - loss: 1.6307 - val_accuracy: 0.7989 - val_loss: 1.0502 - learning_rate: 3.0000e-04
# Epoch 74/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5456 - loss: 1.6520 - val_accuracy: 0.7972 - val_loss: 1.0429 - learning_rate: 3.0000e-04
# Epoch 75/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5871 - loss: 1.5712 - val_accuracy: 0.8096 - val_loss: 1.0123 - learning_rate: 3.0000e-04
# Epoch 76/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5701 - loss: 1.5814 - val_accuracy: 0.8132 - val_loss: 1.0021 - learning_rate: 3.0000e-04
# Epoch 77/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5406 - loss: 1.6116 - val_accuracy: 0.8043 - val_loss: 0.9879 - learning_rate: 3.0000e-04
# Epoch 78/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.5895 - loss: 1.5440 - val_accuracy: 0.7989 - val_loss: 0.9786 - learning_rate: 3.0000e-04
# Epoch 79/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5726 - loss: 1.5382 - val_accuracy: 0.8114 - val_loss: 0.9543 - learning_rate: 3.0000e-04
# Epoch 80/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5952 - loss: 1.5133 - val_accuracy: 0.8274 - val_loss: 0.9150 - learning_rate: 3.0000e-04
# Epoch 81/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6025 - loss: 1.4764 - val_accuracy: 0.8114 - val_loss: 0.9223 - learning_rate: 3.0000e-04
# Epoch 82/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.6101 - loss: 1.4624 - val_accuracy: 0.8238 - val_loss: 0.9041 - learning_rate: 3.0000e-04
# Epoch 83/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5924 - loss: 1.4380 - val_accuracy: 0.8203 - val_loss: 0.8869 - learning_rate: 3.0000e-04
# Epoch 84/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5977 - loss: 1.4383 - val_accuracy: 0.8203 - val_loss: 0.9012 - learning_rate: 3.0000e-04
# Epoch 85/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6067 - loss: 1.4757 - val_accuracy: 0.8256 - val_loss: 0.8661 - learning_rate: 3.0000e-04
# Epoch 86/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.6180 - loss: 1.4193 - val_accuracy: 0.8238 - val_loss: 0.8395 - learning_rate: 3.0000e-04
# Epoch 87/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5997 - loss: 1.3922 - val_accuracy: 0.8292 - val_loss: 0.8427 - learning_rate: 3.0000e-04
# Epoch 88/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6147 - loss: 1.3913 - val_accuracy: 0.8274 - val_loss: 0.8348 - learning_rate: 3.0000e-04
# Epoch 89/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6253 - loss: 1.4002 - val_accuracy: 0.8452 - val_loss: 0.7993 - learning_rate: 3.0000e-04
# Epoch 90/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.6268 - loss: 1.3936 - val_accuracy: 0.8167 - val_loss: 0.8336 - learning_rate: 3.0000e-04
# Epoch 91/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.6142 - loss: 1.3932 - val_accuracy: 0.8470 - val_loss: 0.7837 - learning_rate: 3.0000e-04
# Epoch 92/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6431 - loss: 1.2892 - val_accuracy: 0.8452 - val_loss: 0.7626 - learning_rate: 3.0000e-04
# Epoch 93/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.6397 - loss: 1.3175 - val_accuracy: 0.8452 - val_loss: 0.7666 - learning_rate: 3.0000e-04
# Epoch 94/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.6374 - loss: 1.3093 - val_accuracy: 0.8399 - val_loss: 0.7536 - learning_rate: 3.0000e-04
# Epoch 95/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6301 - loss: 1.3010 - val_accuracy: 0.8505 - val_loss: 0.7473 - learning_rate: 3.0000e-04
# Epoch 96/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6530 - loss: 1.2714 - val_accuracy: 0.8416 - val_loss: 0.7511 - learning_rate: 3.0000e-04
# Epoch 97/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.6493 - loss: 1.2471 - val_accuracy: 0.8594 - val_loss: 0.7206 - learning_rate: 3.0000e-04
# Epoch 98/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.6728 - loss: 1.2292 - val_accuracy: 0.8523 - val_loss: 0.7028 - learning_rate: 3.0000e-04
# Epoch 99/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6563 - loss: 1.2269 - val_accuracy: 0.8434 - val_loss: 0.7152 - learning_rate: 3.0000e-04
# Epoch 100/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.6472 - loss: 1.2441 - val_accuracy: 0.8523 - val_loss: 0.6967 - learning_rate: 3.0000e-04
# Epoch 101/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.6612 - loss: 1.2004 - val_accuracy: 0.8541 - val_loss: 0.6792 - learning_rate: 3.0000e-04
# Epoch 102/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6607 - loss: 1.2342 - val_accuracy: 0.8648 - val_loss: 0.6576 - learning_rate: 3.0000e-04
# Epoch 103/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.6826 - loss: 1.1886 - val_accuracy: 0.8541 - val_loss: 0.6529 - learning_rate: 3.0000e-04
# Epoch 104/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7069 - loss: 1.1133 - val_accuracy: 0.8630 - val_loss: 0.6534 - learning_rate: 3.0000e-04
# Epoch 105/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6857 - loss: 1.1366 - val_accuracy: 0.8470 - val_loss: 0.6631 - learning_rate: 3.0000e-04
# Epoch 106/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6858 - loss: 1.1655 - val_accuracy: 0.8452 - val_loss: 0.6533 - learning_rate: 3.0000e-04
# Epoch 107/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.6776 - loss: 1.1492 - val_accuracy: 0.8630 - val_loss: 0.6269 - learning_rate: 3.0000e-04
# Epoch 108/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.6912 - loss: 1.1139 - val_accuracy: 0.8701 - val_loss: 0.6124 - learning_rate: 3.0000e-04
# Epoch 109/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6946 - loss: 1.1208 - val_accuracy: 0.8541 - val_loss: 0.6156 - learning_rate: 3.0000e-04
# Epoch 110/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6794 - loss: 1.1216 - val_accuracy: 0.8594 - val_loss: 0.6098 - learning_rate: 3.0000e-04
# Epoch 111/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.6623 - loss: 1.1366 - val_accuracy: 0.8648 - val_loss: 0.5994 - learning_rate: 3.0000e-04
# Epoch 112/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.6869 - loss: 1.0986 - val_accuracy: 0.8683 - val_loss: 0.5871 - learning_rate: 3.0000e-04
# Epoch 113/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.6908 - loss: 1.1009 - val_accuracy: 0.8754 - val_loss: 0.5814 - learning_rate: 3.0000e-04
# Epoch 114/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.6971 - loss: 1.0505 - val_accuracy: 0.8790 - val_loss: 0.5612 - learning_rate: 3.0000e-04
# Epoch 115/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.6980 - loss: 1.0545 - val_accuracy: 0.8665 - val_loss: 0.5682 - learning_rate: 3.0000e-04
# Epoch 116/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7089 - loss: 1.0748 - val_accuracy: 0.8737 - val_loss: 0.5652 - learning_rate: 3.0000e-04
# Epoch 117/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.7031 - loss: 1.0595 - val_accuracy: 0.8754 - val_loss: 0.5442 - learning_rate: 3.0000e-04
# Epoch 118/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7174 - loss: 1.0201 - val_accuracy: 0.8719 - val_loss: 0.5407 - learning_rate: 3.0000e-04
# Epoch 119/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.7001 - loss: 1.0430 - val_accuracy: 0.8826 - val_loss: 0.5357 - learning_rate: 3.0000e-04
# Epoch 120/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7168 - loss: 1.0405 - val_accuracy: 0.8683 - val_loss: 0.5427 - learning_rate: 3.0000e-04
# Epoch 121/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.6994 - loss: 1.0517 - val_accuracy: 0.8754 - val_loss: 0.5266 - learning_rate: 3.0000e-04
# Epoch 122/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7166 - loss: 1.0005 - val_accuracy: 0.8737 - val_loss: 0.5222 - learning_rate: 3.0000e-04
# Epoch 123/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7186 - loss: 0.9895 - val_accuracy: 0.8790 - val_loss: 0.5131 - learning_rate: 3.0000e-04
# Epoch 124/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7287 - loss: 0.9421 - val_accuracy: 0.8772 - val_loss: 0.5064 - learning_rate: 3.0000e-04
# Epoch 125/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7488 - loss: 0.9226 - val_accuracy: 0.8879 - val_loss: 0.4840 - learning_rate: 3.0000e-04
# Epoch 126/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7094 - loss: 1.0034 - val_accuracy: 0.8915 - val_loss: 0.4948 - learning_rate: 3.0000e-04
# Epoch 127/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7315 - loss: 0.9603 - val_accuracy: 0.8950 - val_loss: 0.4849 - learning_rate: 3.0000e-04
# Epoch 128/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7231 - loss: 0.9897 - val_accuracy: 0.8950 - val_loss: 0.4632 - learning_rate: 3.0000e-04
# Epoch 129/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7391 - loss: 0.9187 - val_accuracy: 0.8897 - val_loss: 0.4687 - learning_rate: 3.0000e-04
# Epoch 130/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7448 - loss: 0.9246 - val_accuracy: 0.8861 - val_loss: 0.4813 - learning_rate: 3.0000e-04
# Epoch 131/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7415 - loss: 0.9323 - val_accuracy: 0.8790 - val_loss: 0.4707 - learning_rate: 3.0000e-04
# Epoch 132/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7438 - loss: 0.9500 - val_accuracy: 0.8772 - val_loss: 0.4716 - learning_rate: 3.0000e-04
# Epoch 133/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.7377 - loss: 0.9500 - val_accuracy: 0.9075 - val_loss: 0.4514 - learning_rate: 3.0000e-04
# Epoch 134/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7435 - loss: 0.8908 - val_accuracy: 0.9004 - val_loss: 0.4439 - learning_rate: 3.0000e-04
# Epoch 135/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7345 - loss: 0.9188 - val_accuracy: 0.8968 - val_loss: 0.4549 - learning_rate: 3.0000e-04
# Epoch 136/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7540 - loss: 0.9138 - val_accuracy: 0.9093 - val_loss: 0.4306 - learning_rate: 3.0000e-04
# Epoch 137/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.7444 - loss: 0.8980 - val_accuracy: 0.9093 - val_loss: 0.4313 - learning_rate: 3.0000e-04
# Epoch 138/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7459 - loss: 0.8988 - val_accuracy: 0.9075 - val_loss: 0.4337 - learning_rate: 3.0000e-04
# Epoch 139/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7432 - loss: 0.8625 - val_accuracy: 0.9057 - val_loss: 0.4173 - learning_rate: 3.0000e-04
# Epoch 140/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7535 - loss: 0.8806 - val_accuracy: 0.9057 - val_loss: 0.4171 - learning_rate: 3.0000e-04
# Epoch 141/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7529 - loss: 0.8938 - val_accuracy: 0.9039 - val_loss: 0.4248 - learning_rate: 3.0000e-04
# Epoch 142/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.7399 - loss: 0.9016 - val_accuracy: 0.9075 - val_loss: 0.4281 - learning_rate: 3.0000e-04
# Epoch 143/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7567 - loss: 0.8648 - val_accuracy: 0.9075 - val_loss: 0.4115 - learning_rate: 3.0000e-04
# Epoch 144/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7914 - loss: 0.7624 - val_accuracy: 0.9004 - val_loss: 0.3894 - learning_rate: 3.0000e-04
# Epoch 145/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.7746 - loss: 0.8420 - val_accuracy: 0.9146 - val_loss: 0.3858 - learning_rate: 3.0000e-04
# Epoch 146/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7587 - loss: 0.8587 - val_accuracy: 0.9004 - val_loss: 0.3966 - learning_rate: 3.0000e-04
# Epoch 147/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7681 - loss: 0.8267 - val_accuracy: 0.9199 - val_loss: 0.3706 - learning_rate: 3.0000e-04
# Epoch 148/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7759 - loss: 0.7972 - val_accuracy: 0.9110 - val_loss: 0.3618 - learning_rate: 3.0000e-04
# Epoch 149/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.7682 - loss: 0.8328 - val_accuracy: 0.9164 - val_loss: 0.3651 - learning_rate: 3.0000e-04
# Epoch 150/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7668 - loss: 0.8158 - val_accuracy: 0.9110 - val_loss: 0.3634 - learning_rate: 3.0000e-04
# Epoch 151/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7632 - loss: 0.8198 - val_accuracy: 0.9110 - val_loss: 0.3758 - learning_rate: 3.0000e-04
# Epoch 152/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7726 - loss: 0.8024 - val_accuracy: 0.9235 - val_loss: 0.3510 - learning_rate: 3.0000e-04
# Epoch 153/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7743 - loss: 0.8085 - val_accuracy: 0.9110 - val_loss: 0.3492 - learning_rate: 3.0000e-04
# Epoch 154/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7908 - loss: 0.7668 - val_accuracy: 0.9146 - val_loss: 0.3512 - learning_rate: 3.0000e-04
# Epoch 155/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7617 - loss: 0.7944 - val_accuracy: 0.9093 - val_loss: 0.3443 - learning_rate: 3.0000e-04
# Epoch 156/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.7745 - loss: 0.7769 - val_accuracy: 0.9146 - val_loss: 0.3370 - learning_rate: 3.0000e-04
# Epoch 157/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7754 - loss: 0.7787 - val_accuracy: 0.9128 - val_loss: 0.3410 - learning_rate: 3.0000e-04
# Epoch 158/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7802 - loss: 0.7452 - val_accuracy: 0.9164 - val_loss: 0.3405 - learning_rate: 3.0000e-04
# Epoch 159/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.7959 - loss: 0.7528 - val_accuracy: 0.9128 - val_loss: 0.3230 - learning_rate: 3.0000e-04
# Epoch 160/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.7911 - loss: 0.7601 - val_accuracy: 0.9199 - val_loss: 0.3219 - learning_rate: 3.0000e-04
# Epoch 161/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7736 - loss: 0.7688 - val_accuracy: 0.9164 - val_loss: 0.3275 - learning_rate: 3.0000e-04
# Epoch 162/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7799 - loss: 0.7721 - val_accuracy: 0.9128 - val_loss: 0.3105 - learning_rate: 3.0000e-04
# Epoch 163/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7814 - loss: 0.7603 - val_accuracy: 0.9164 - val_loss: 0.3130 - learning_rate: 3.0000e-04
# Epoch 164/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8110 - loss: 0.6992 - val_accuracy: 0.9199 - val_loss: 0.3034 - learning_rate: 3.0000e-04
# Epoch 165/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7916 - loss: 0.7390 - val_accuracy: 0.9181 - val_loss: 0.3063 - learning_rate: 3.0000e-04
# Epoch 166/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7874 - loss: 0.7574 - val_accuracy: 0.9199 - val_loss: 0.3055 - learning_rate: 3.0000e-04
# Epoch 167/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8074 - loss: 0.6778 - val_accuracy: 0.9306 - val_loss: 0.2914 - learning_rate: 3.0000e-04
# Epoch 168/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8117 - loss: 0.7170 - val_accuracy: 0.9306 - val_loss: 0.3029 - learning_rate: 3.0000e-04
# Epoch 169/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7770 - loss: 0.7535 - val_accuracy: 0.9270 - val_loss: 0.2905 - learning_rate: 3.0000e-04
# Epoch 170/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8033 - loss: 0.7054 - val_accuracy: 0.9217 - val_loss: 0.2955 - learning_rate: 3.0000e-04
# Epoch 171/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7986 - loss: 0.7192 - val_accuracy: 0.9306 - val_loss: 0.2866 - learning_rate: 3.0000e-04
# Epoch 172/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7832 - loss: 0.7360 - val_accuracy: 0.9217 - val_loss: 0.2897 - learning_rate: 3.0000e-04
# Epoch 173/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7828 - loss: 0.7420 - val_accuracy: 0.9235 - val_loss: 0.2844 - learning_rate: 3.0000e-04
# Epoch 174/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7947 - loss: 0.6994 - val_accuracy: 0.9253 - val_loss: 0.2800 - learning_rate: 3.0000e-04
# Epoch 175/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8071 - loss: 0.6769 - val_accuracy: 0.9288 - val_loss: 0.2770 - learning_rate: 3.0000e-04
# Epoch 176/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8214 - loss: 0.6510 - val_accuracy: 0.9324 - val_loss: 0.2719 - learning_rate: 3.0000e-04
# Epoch 177/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8125 - loss: 0.6758 - val_accuracy: 0.9306 - val_loss: 0.2732 - learning_rate: 3.0000e-04
# Epoch 178/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8234 - loss: 0.6714 - val_accuracy: 0.9359 - val_loss: 0.2686 - learning_rate: 3.0000e-04
# Epoch 179/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8180 - loss: 0.6439 - val_accuracy: 0.9359 - val_loss: 0.2693 - learning_rate: 3.0000e-04
# Epoch 180/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8214 - loss: 0.6584 - val_accuracy: 0.9395 - val_loss: 0.2583 - learning_rate: 3.0000e-04
# Epoch 181/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8109 - loss: 0.6954 - val_accuracy: 0.9306 - val_loss: 0.2595 - learning_rate: 3.0000e-04
# Epoch 182/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8103 - loss: 0.6650 - val_accuracy: 0.9342 - val_loss: 0.2620 - learning_rate: 3.0000e-04
# Epoch 183/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8241 - loss: 0.6389 - val_accuracy: 0.9199 - val_loss: 0.2698 - learning_rate: 3.0000e-04
# Epoch 184/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8132 - loss: 0.6953 - val_accuracy: 0.9306 - val_loss: 0.2504 - learning_rate: 3.0000e-04
# Epoch 185/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8247 - loss: 0.6268 - val_accuracy: 0.9306 - val_loss: 0.2556 - learning_rate: 3.0000e-04
# Epoch 186/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8104 - loss: 0.6319 - val_accuracy: 0.9324 - val_loss: 0.2421 - learning_rate: 3.0000e-04
# Epoch 187/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8188 - loss: 0.6358 - val_accuracy: 0.9306 - val_loss: 0.2595 - learning_rate: 3.0000e-04
# Epoch 188/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8162 - loss: 0.6500 - val_accuracy: 0.9359 - val_loss: 0.2349 - learning_rate: 3.0000e-04
# Epoch 189/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8113 - loss: 0.6237 - val_accuracy: 0.9431 - val_loss: 0.2272 - learning_rate: 3.0000e-04
# Epoch 190/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8390 - loss: 0.6133 - val_accuracy: 0.9359 - val_loss: 0.2298 - learning_rate: 3.0000e-04
# Epoch 191/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8290 - loss: 0.6347 - val_accuracy: 0.9377 - val_loss: 0.2372 - learning_rate: 3.0000e-04
# Epoch 192/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8247 - loss: 0.6360 - val_accuracy: 0.9342 - val_loss: 0.2298 - learning_rate: 3.0000e-04
# Epoch 193/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.8316 - loss: 0.5851 - val_accuracy: 0.9342 - val_loss: 0.2327 - learning_rate: 3.0000e-04
# Epoch 194/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8212 - loss: 0.5977 - val_accuracy: 0.9395 - val_loss: 0.2155 - learning_rate: 3.0000e-04
# Epoch 195/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8261 - loss: 0.6161 - val_accuracy: 0.9395 - val_loss: 0.2243 - learning_rate: 3.0000e-04
# Epoch 196/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.8343 - loss: 0.6100 - val_accuracy: 0.9288 - val_loss: 0.2273 - learning_rate: 3.0000e-04
# Epoch 197/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8247 - loss: 0.6360 - val_accuracy: 0.9377 - val_loss: 0.2342 - learning_rate: 3.0000e-04
# Epoch 198/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8319 - loss: 0.5683 - val_accuracy: 0.9359 - val_loss: 0.2245 - learning_rate: 3.0000e-04
# Epoch 199/250
# 70/71 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8247 - loss: 0.6351
# Epoch 199: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8247 - loss: 0.6346 - val_accuracy: 0.9413 - val_loss: 0.2182 - learning_rate: 3.0000e-04
# Epoch 200/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8367 - loss: 0.6022 - val_accuracy: 0.9377 - val_loss: 0.2018 - learning_rate: 1.5000e-04
# Epoch 201/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8439 - loss: 0.5576 - val_accuracy: 0.9431 - val_loss: 0.2026 - learning_rate: 1.5000e-04
# Epoch 202/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8519 - loss: 0.5375 - val_accuracy: 0.9520 - val_loss: 0.1983 - learning_rate: 1.5000e-04
# Epoch 203/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8336 - loss: 0.5608 - val_accuracy: 0.9466 - val_loss: 0.1989 - learning_rate: 1.5000e-04
# Epoch 204/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8439 - loss: 0.5566 - val_accuracy: 0.9502 - val_loss: 0.2021 - learning_rate: 1.5000e-04
# Epoch 205/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8478 - loss: 0.5358 - val_accuracy: 0.9431 - val_loss: 0.1932 - learning_rate: 1.5000e-04
# Epoch 206/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8468 - loss: 0.5328 - val_accuracy: 0.9502 - val_loss: 0.1888 - learning_rate: 1.5000e-04
# Epoch 207/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8578 - loss: 0.5097 - val_accuracy: 0.9502 - val_loss: 0.1882 - learning_rate: 1.5000e-04
# Epoch 208/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8343 - loss: 0.5696 - val_accuracy: 0.9466 - val_loss: 0.1839 - learning_rate: 1.5000e-04
# Epoch 209/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8503 - loss: 0.5226 - val_accuracy: 0.9537 - val_loss: 0.1796 - learning_rate: 1.5000e-04
# Epoch 210/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8417 - loss: 0.5440 - val_accuracy: 0.9573 - val_loss: 0.1764 - learning_rate: 1.5000e-04
# Epoch 211/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.8458 - loss: 0.5561 - val_accuracy: 0.9609 - val_loss: 0.1796 - learning_rate: 1.5000e-04
# Epoch 212/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8466 - loss: 0.5475 - val_accuracy: 0.9555 - val_loss: 0.1773 - learning_rate: 1.5000e-04
# Epoch 213/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8605 - loss: 0.4986 - val_accuracy: 0.9591 - val_loss: 0.1726 - learning_rate: 1.5000e-04
# Epoch 214/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8559 - loss: 0.5207 - val_accuracy: 0.9626 - val_loss: 0.1759 - learning_rate: 1.5000e-04
# Epoch 215/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.8419 - loss: 0.5273 - val_accuracy: 0.9644 - val_loss: 0.1686 - learning_rate: 1.5000e-04
# Epoch 216/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8627 - loss: 0.5023 - val_accuracy: 0.9626 - val_loss: 0.1715 - learning_rate: 1.5000e-04
# Epoch 217/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8428 - loss: 0.5196 - val_accuracy: 0.9609 - val_loss: 0.1715 - learning_rate: 1.5000e-04
# Epoch 218/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8477 - loss: 0.5207 - val_accuracy: 0.9537 - val_loss: 0.1747 - learning_rate: 1.5000e-04
# Epoch 219/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8438 - loss: 0.5158 - val_accuracy: 0.9502 - val_loss: 0.1753 - learning_rate: 1.5000e-04
# Epoch 220/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8544 - loss: 0.5069
# Epoch 220: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8544 - loss: 0.5069 - val_accuracy: 0.9537 - val_loss: 0.1704 - learning_rate: 1.5000e-04
# Epoch 221/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.8564 - loss: 0.5029 - val_accuracy: 0.9591 - val_loss: 0.1693 - learning_rate: 7.5000e-05
# Epoch 222/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8665 - loss: 0.4635 - val_accuracy: 0.9555 - val_loss: 0.1644 - learning_rate: 7.5000e-05
# Epoch 223/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8540 - loss: 0.5133 - val_accuracy: 0.9591 - val_loss: 0.1650 - learning_rate: 7.5000e-05
# Epoch 224/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8637 - loss: 0.5088 - val_accuracy: 0.9609 - val_loss: 0.1573 - learning_rate: 7.5000e-05
# Epoch 225/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8505 - loss: 0.5252 - val_accuracy: 0.9626 - val_loss: 0.1602 - learning_rate: 7.5000e-05
# Epoch 226/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8671 - loss: 0.4596 - val_accuracy: 0.9591 - val_loss: 0.1614 - learning_rate: 7.5000e-05
# Epoch 227/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8562 - loss: 0.5171 - val_accuracy: 0.9609 - val_loss: 0.1598 - learning_rate: 7.5000e-05
# Epoch 228/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8504 - loss: 0.4892 - val_accuracy: 0.9662 - val_loss: 0.1596 - learning_rate: 7.5000e-05
# Epoch 229/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8631 - loss: 0.4844
# Epoch 229: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.8631 - loss: 0.4844 - val_accuracy: 0.9537 - val_loss: 0.1634 - learning_rate: 7.5000e-05
# Epoch 230/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8626 - loss: 0.4840 - val_accuracy: 0.9591 - val_loss: 0.1598 - learning_rate: 3.7500e-05
# Epoch 231/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8684 - loss: 0.4638 - val_accuracy: 0.9591 - val_loss: 0.1566 - learning_rate: 3.7500e-05
# Epoch 232/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8764 - loss: 0.4577 - val_accuracy: 0.9573 - val_loss: 0.1562 - learning_rate: 3.7500e-05
# Epoch 233/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8677 - loss: 0.4620 - val_accuracy: 0.9626 - val_loss: 0.1531 - learning_rate: 3.7500e-05
# Epoch 234/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8695 - loss: 0.4773 - val_accuracy: 0.9626 - val_loss: 0.1541 - learning_rate: 3.7500e-05
# Epoch 235/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8709 - loss: 0.4791 - val_accuracy: 0.9591 - val_loss: 0.1555 - learning_rate: 3.7500e-05
# Epoch 236/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8666 - loss: 0.4630 - val_accuracy: 0.9591 - val_loss: 0.1540 - learning_rate: 3.7500e-05
# Epoch 237/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8715 - loss: 0.4481 - val_accuracy: 0.9609 - val_loss: 0.1538 - learning_rate: 3.7500e-05
# Epoch 238/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8643 - loss: 0.4705 - val_accuracy: 0.9644 - val_loss: 0.1523 - learning_rate: 3.7500e-05
# Epoch 239/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8646 - loss: 0.4751 - val_accuracy: 0.9644 - val_loss: 0.1519 - learning_rate: 3.7500e-05
# Epoch 240/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.8808 - loss: 0.4718 - val_accuracy: 0.9662 - val_loss: 0.1521 - learning_rate: 3.7500e-05
# Epoch 241/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8798 - loss: 0.4671 - val_accuracy: 0.9609 - val_loss: 0.1502 - learning_rate: 3.7500e-05
# Epoch 242/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8742 - loss: 0.4705 - val_accuracy: 0.9573 - val_loss: 0.1523 - learning_rate: 3.7500e-05
# Epoch 243/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8695 - loss: 0.4637 - val_accuracy: 0.9609 - val_loss: 0.1494 - learning_rate: 3.7500e-05
# Epoch 244/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.8589 - loss: 0.4766 - val_accuracy: 0.9626 - val_loss: 0.1507 - learning_rate: 3.7500e-05
# Epoch 245/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.8563 - loss: 0.4744 - val_accuracy: 0.9609 - val_loss: 0.1484 - learning_rate: 3.7500e-05
# Epoch 246/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8843 - loss: 0.4505 - val_accuracy: 0.9573 - val_loss: 0.1480 - learning_rate: 3.7500e-05
# Epoch 247/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8740 - loss: 0.4588 - val_accuracy: 0.9537 - val_loss: 0.1486 - learning_rate: 3.7500e-05
# Epoch 248/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8645 - loss: 0.4727 - val_accuracy: 0.9609 - val_loss: 0.1480 - learning_rate: 3.7500e-05
# Epoch 249/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8844 - loss: 0.4300 - val_accuracy: 0.9591 - val_loss: 0.1473 - learning_rate: 3.7500e-05
# Epoch 250/250
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8804 - loss: 0.4233 - val_accuracy: 0.9591 - val_loss: 0.1470 - learning_rate: 3.7500e-05
#  Best Epoch: 250
#  Final Train Accuracy: 0.8789
#  Best Validation Accuracy: 0.9591
#  Final Train Loss: 0.4347
#  Best Validation Loss: 0.1470
#
#  Test Loss: 1.7523,  Test Accuracy: 0.8153
